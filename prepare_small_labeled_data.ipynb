# %%
import numpy as np 
import pandas as pd 
import random

import cv2
import os

# %%
root_dir = r'D:\2020\Trainings\self_supervised_learning'
images_dir = os.path.join(root_dir,'dataset')
train_labels_path = os.path.join(root_dir,'dataset','annotations','flowers_recognition_train.csv')
test_labels_path = os.path.join(root_dir,'dataset','annotations','flowers_recognition_test.csv')

# %%
train_labels_path
# Out:
# 'D:\\2020\\Trainings\\self_supervised_learning\\dataset\\annotations\\flowers_recognition_train.csv'

# %%
train_df = pd.read_csv(train_labels_path,usecols=['FileName','Label','ClassName'])
test_df = pd.read_csv(test_labels_path,usecols=['FileName','Label','ClassName'])

# %%
train_df.head()
# Out:
#            FileName  Label ClassName
# 0  daisy_000001.png      0     daisy
# 1  daisy_000002.png      0     daisy
# 2  daisy_000003.png      0     daisy
# 3  daisy_000004.png      0     daisy
# 4  daisy_000005.png      0     daisy

# %%
per_labeled_data=10
small_labeled_data=pd.DataFrame(columns=['FileName','Label','ClassName'])
small_labeled_data
# Out:
# Empty DataFrame
# Columns: [FileName, Label, ClassName]
# Index: []

# %%
for labels in range(5):
    data=train_df[train_df['Label']==labels]
    num_labeled_samp=int((len(data)/100)*per_labeled_data)
    print(num_labeled_samp)
    idxs = random.sample(range(1, len(data)), num_labeled_samp)
    data_selected=data.iloc[idxs]
    small_labeled_data = pd.concat([small_labeled_data,data_selected])
# Out:
# 70
# 99
# 72
# 67
# 92

# %%
small_labeled_data
# Out:
#               FileName Label ClassName
# 364   daisy_000402.png     0     daisy
# 246   daisy_000273.png     0     daisy
# 527   daisy_000572.png     0     daisy
# 424   daisy_000465.png     0     daisy
# 615   daisy_000667.png     0     daisy
# 184   daisy_000201.png     0     daisy
# 492   daisy_000536.png     0     daisy
# 375   daisy_000413.png     0     daisy
# 244   daisy_000271.png     0     daisy
# 404   daisy_000443.png     0     daisy
# 677   daisy_000736.png     0     daisy
# 373   daisy_000411.png     0     daisy
# 447   daisy_000488.png     0     daisy
# 390   daisy_000428.png     0     daisy
# 172   daisy_000188.png     0     daisy
# 419   daisy_000460.png     0     daisy
# 25    daisy_000027.png     0     daisy
# 257   daisy_000285.png     0     daisy
# 521   daisy_000566.png     0     daisy
# 66    daisy_000068.png     0     daisy
# 617   daisy_000669.png     0     daisy
# 312   daisy_000343.png     0     daisy
# 240   daisy_000266.png     0     daisy
# 68    daisy_000073.png     0     daisy
# 282   daisy_000311.png     0     daisy
# 451   daisy_000492.png     0     daisy
# 261   daisy_000289.png     0     daisy
# 335   daisy_000369.png     0     daisy
# 29    daisy_000031.png     0     daisy
# 278   daisy_000307.png     0     daisy
# ...                ...   ...       ...
# 3346  tulip_000264.png     4     tulip
# 3814  tulip_000765.png     4     tulip
# 3980  tulip_000940.png     4     tulip
# 3122  tulip_000025.png     4     tulip
# 3202  tulip_000108.png     4     tulip
# 3247  tulip_000156.png     4     tulip
# 3604  tulip_000541.png     4     tulip
# 3483  tulip_000412.png     4     tulip
# 3559  tulip_000495.png     4     tulip
# 3573  tulip_000510.png     4     tulip
# 3286  tulip_000200.png     4     tulip
# 3940  tulip_000895.png     4     tulip
# 3226  tulip_000133.png     4     tulip
# 3794  tulip_000745.png     4     tulip
# 3607  tulip_000544.png     4     tulip
# 3962  tulip_000922.png     4     tulip
# 3437  tulip_000362.png     4     tulip
# 3516  tulip_000447.png     4     tulip
# 3521  tulip_000453.png     4     tulip
# 3266  tulip_000178.png     4     tulip
# 3973  tulip_000933.png     4     tulip
# 3302  tulip_000216.png     4     tulip
# 3498  tulip_000429.png     4     tulip
# 3353  tulip_000273.png     4     tulip
# 3782  tulip_000732.png     4     tulip
# 3550  tulip_000485.png     4     tulip
# 3650  tulip_000589.png     4     tulip
# 3365  tulip_000285.png     4     tulip
# 3449  tulip_000374.png     4     tulip
# 3897  tulip_000851.png     4     tulip
#
# [400 rows x 3 columns]

# %%
dest_path=os.path.join('dataset','annotations')
if not os.path.exists(dest_path):
    os.mkdir(dest_path)

small_labeled_data.to_csv(os.path.join(dest_path,'small_labeled_data.csv'),index=False)
