# %%
import numpy as np 
import pandas as pd 
import random

import cv2
import os

# %%
root_dir = r'D:\2020\Trainings\self_supervised_learning'
images_dir = os.path.join(root_dir,'dataset')
train_labels_path = os.path.join(root_dir,'dataset','annotations','flowers_recognition_train.csv')
test_labels_path = os.path.join(root_dir,'dataset','annotations','flowers_recognition_test.csv')

# %%
train_labels_path
# Out:
# 'D:\\2020\\Trainings\\self_supervised_learning\\dataset\\annotations\\flowers_recognition_train.csv'

# %%
train_df = pd.read_csv(train_labels_path,usecols=['FileName','Label','ClassName'])
test_df = pd.read_csv(test_labels_path,usecols=['FileName','Label','ClassName'])

# %%
train_df.head()
# Out:
#                                             FileName  Label ClassName
# 0  D:\2020\Trainings\self_supervised_learning\dat...      0     daisy
# 1  D:\2020\Trainings\self_supervised_learning\dat...      0     daisy
# 2  D:\2020\Trainings\self_supervised_learning\dat...      0     daisy
# 3  D:\2020\Trainings\self_supervised_learning\dat...      0     daisy
# 4  D:\2020\Trainings\self_supervised_learning\dat...      0     daisy

# %%
per_labeled_data=10
small_labeled_data=pd.DataFrame(columns=['FileName','Label','ClassName'])
small_labeled_data
# Out:
# Empty DataFrame
# Columns: [FileName, Label, ClassName]
# Index: []

# %%
for labels in range(5):
    data=train_df[train_df['Label']==labels]
    num_labeled_samp=int((len(data)/100)*per_labeled_data)
    print(num_labeled_samp)
    idxs = random.sample(range(1, len(data)), num_labeled_samp)
    data_selected=data.iloc[idxs]
    small_labeled_data = pd.concat([small_labeled_data,data_selected])
# Out:
# 70
# 99
# 72
# 67
# 92

# %%
small_labeled_data
# Out:
#                                                FileName Label ClassName
# 547   D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 503   D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 83    D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 95    D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 323   D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 15    D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 502   D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 580   D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 423   D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 663   D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 673   D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 555   D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 541   D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 216   D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 424   D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 277   D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 308   D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 22    D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 483   D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 551   D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 596   D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 626   D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 99    D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 75    D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 259   D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 675   D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 368   D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 340   D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 653   D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# 11    D:\2020\Trainings\self_supervised_learning\dat...     0     daisy
# ...                                                 ...   ...       ...
# 3713  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3863  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3306  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3377  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3886  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3309  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3819  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3317  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3996  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3503  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3183  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3836  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3207  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3641  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3992  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3252  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3680  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3609  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3624  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3969  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3378  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3501  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3808  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3857  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3546  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3227  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3847  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3162  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3881  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
# 3478  D:\2020\Trainings\self_supervised_learning\dat...     4     tulip
#
# [400 rows x 3 columns]

# %%
dest_path=os.path.join('dataset','annotations')
if not os.path.exists(dest_path):
    os.mkdir(dest_path)

small_labeled_data.to_csv(os.path.join(dest_path,'small_labeled_data.csv'),index=False)
